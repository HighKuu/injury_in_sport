# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Exploration
# Ici dans ce collab, chaque cellule sera commenté pour bien comprendre le cheminement. Cela aidera également à bien structurer/organiser mes travaux

# %%
# Chargement du Dataset
url = '/content/collegiate_athlete_injury_dataset.csv'
df = pd.read_csv(url)
df.info() # Permet de voir si il y a des valeurs manquantes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Athlete_ID                200 non-null    object
#  1   Age                       200 non-null    int64
#  2   Gender                    200 non-null    object
#  3   Height_cm                 200 non-null    int64
#  4   Weight_kg                 200 non-null    int64
#  5   Position                  200 non-null    object
#  6   Training_Intensity        200 non-null    int64
#  7   Training_Hours_Per_Week   200 non-null    int64
#  8   Recovery_Days_Per_Week    200 non-null    int64
#  9   Match_Count_Per_Week      200 non-null    int64
#  10  Rest_Between_Events_Days  200 non-null    int64
#  11  Fatigue_Score             200 non-null    int64
#  12  Performance_Score         200 non-null    int64
#  13  Team_Contribution_Score   200 non-null    int64
# ...

# %%
# Résumé des statistiques descriptives
df.describe()
# Out:
#               Age   Height_cm   Weight_kg  Training_Intensity  \
# count  200.000000  200.000000  200.000000           200.00000
# mean    21.170000  180.805000   77.475000             5.10500
# std      2.002787   11.529598   12.440789             2.49904
# min     18.000000  160.000000   55.000000             1.00000
# 25%     19.000000  171.000000   67.000000             3.00000
# 50%     21.000000  182.500000   77.500000             5.00000
# 75%     23.000000  191.000000   89.000000             7.00000
# max     24.000000  199.000000   99.000000             9.00000
#
#        Training_Hours_Per_Week  Recovery_Days_Per_Week  Match_Count_Per_Week  \
# count               200.000000              200.000000            200.000000
# mean                 11.315000                1.985000              2.385000
# std                   4.438952                0.811212              1.154748
# min                   5.000000                1.000000              1.000000
# ...

# %%
# Structure du Dataset (Ligne/Cologne)
df.shape
# Out:
# (200, 17)

# %%
#Nom des colonnes
df.columns
# Out:
# Index(['Athlete_ID', 'Age', 'Gender', 'Height_cm', 'Weight_kg', 'Position',
#        'Training_Intensity', 'Training_Hours_Per_Week',
#        'Recovery_Days_Per_Week', 'Match_Count_Per_Week',
#        'Rest_Between_Events_Days', 'Fatigue_Score', 'Performance_Score',
#        'Team_Contribution_Score', 'Load_Balance_Score', 'ACL_Risk_Score',
#        'Injury_Indicator'],
#       dtype='object')

# %%
df.head()
# Out:
#   Athlete_ID  Age  Gender  Height_cm  Weight_kg Position  Training_Intensity  \
# 0       A001   24  Female        195         99   Center                   2
# 1       A002   21    Male        192         65  Forward                   8
# 2       A003   22    Male        163         83    Guard                   8
# 3       A004   24  Female        192         90    Guard                   1
# 4       A005   20  Female        173         79   Center                   3
#
#    Training_Hours_Per_Week  Recovery_Days_Per_Week  Match_Count_Per_Week  \
# 0                       13                       2                     3
# 1                       14                       1                     3
# 2                        8                       2                     1
# 3                       13                       1                     1
# 4                        9                       1                     2
#
# ...

# %%
# df.rename(columns={'ancien_nom_colonne': 'nouveau_nom_colonne'}, inplace=True)
# Changement des noms de certaine colonne
df.rename(columns={'Gender': 'Genre',
                   'Height_cm': 'Taille_cm',
                   'Weight_kg': 'Poids_kg',
                   'Position': 'Poste'
                   }, inplace= True)

# %%
df.head()
# Out:
#   Athlete_ID  Age   Genre  Taille_cm  Poids_kg    Poste  Training_Intensity  \
# 0       A001   24  Female        195        99   Center                   2
# 1       A002   21    Male        192        65  Forward                   8
# 2       A003   22    Male        163        83    Guard                   8
# 3       A004   24  Female        192        90    Guard                   1
# 4       A005   20  Female        173        79   Center                   3
#
#    Training_Hours_Per_Week  Recovery_Days_Per_Week  Match_Count_Per_Week  \
# 0                       13                       2                     3
# 1                       14                       1                     3
# 2                        8                       2                     1
# 3                       13                       1                     1
# 4                        9                       1                     2
#
#    Rest_Between_Events_Days  Fatigue_Score  Performance_Score  \
# ...

# %%
# Nombre de blessure
df['Injury_Indicator'].sum()
# Out:
# 14

# %%
# Compter le nombre de femme et d'homme
df['Genre'].value_counts()
# Out:
# Genre
# Female    107
# Male       93
# Name: count, dtype: int64

# %%
# L'athlète le plus vieux
df['Age'].max()
# Out:
# 24

# %%
# L'athlète le plus jeune
df['Age'].min()
# Out:
# 18

# %%
df['Taille_cm'].max()
# Out:
# 199

# %%
# Athlte le plus grand (juste par curiosté)
df.loc[df['Taille_cm'].idxmax()]
# Out:
# Athlete_ID                    A053
# Age                             24
# Genre                       Female
# Taille_cm                      199
# Poids_kg                        77
# Poste                        Guard
# Training_Intensity               1
# Training_Hours_Per_Week         10
# Recovery_Days_Per_Week           2
# Match_Count_Per_Week             3
# Rest_Between_Events_Days         2
# Fatigue_Score                    3
# Performance_Score               84
# Team_Contribution_Score         52
# Load_Balance_Score             100
# ACL_Risk_Score                  33
# Injury_Indicator                 0
# Name: 52, dtype: object

# %%
# Athlète le plus grand
df_a = df.loc[df['Taille_cm'].idxmax()].reset_index()
df_a.T
# Out:
#                0    1       2          3         4      5   \
# index  Athlete_ID  Age   Genre  Taille_cm  Poids_kg  Poste
# 52           A053   24  Female        199        77  Guard
#
#                        6                        7                       8   \
# index  Training_Intensity  Training_Hours_Per_Week  Recovery_Days_Per_Week
# 52                      1                       10                       2
#
#                          9                         10             11  \
# index  Match_Count_Per_Week  Rest_Between_Events_Days  Fatigue_Score
# 52                        3                         2              3
#
#                       12                       13                  14  \
# index  Performance_Score  Team_Contribution_Score  Load_Balance_Score
# 52                    84                       52                 100
#
#                    15                16
# index  ACL_Risk_Score  Injury_Indicator
# 52                 33                 0

# %% [markdown]
# # Évaluation de la qualité des données

# %%
df.dtypes
# Out:
# Athlete_ID                  object
# Age                          int64
# Genre                       object
# Taille_cm                    int64
# Poids_kg                     int64
# Poste                       object
# Training_Intensity           int64
# Training_Hours_Per_Week      int64
# Recovery_Days_Per_Week       int64
# Match_Count_Per_Week         int64
# Rest_Between_Events_Days     int64
# Fatigue_Score                int64
# Performance_Score            int64
# Team_Contribution_Score      int64
# Load_Balance_Score           int64
# ACL_Risk_Score               int64
# Injury_Indicator             int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.select_dtypes(include=np.number).corr()
plt.figure(figsize= (8, 6))
sns.heatmap( correlation_matrix, cmap='winter', annot=True,fmt='.1f',center= 0)
plt.title('Corrélation possible entre ≠ variables', family= 'serif',fontweight='bold', size= 12)
plt.show()
# conclu corrélation : ('Load_balance_Score'/'Recovery_days_per_Week')
#          ('ACL_risk_Score'/'Fatigue_score')
#          ('Load_balance_Score'/'Injury_Indicator')

# %%
# Vous avez dit "Outliers"
sns.boxplot(df['Taille_cm'])
# Out:
# <Axes: ylabel='Taille_cm'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df.head()
# Out:
#   Athlete_ID  Age   Genre  Taille_cm  Poids_kg    Poste  Training_Intensity  \
# 0       A001   24  Female        195        99   Center                   2
# 1       A002   21    Male        192        65  Forward                   8
# 2       A003   22    Male        163        83    Guard                   8
# 3       A004   24  Female        192        90    Guard                   1
# 4       A005   20  Female        173        79   Center                   3
#
#    Training_Hours_Per_Week  Recovery_Days_Per_Week  Match_Count_Per_Week  \
# 0                       13                       2                     3
# 1                       14                       1                     3
# 2                        8                       2                     1
# 3                       13                       1                     1
# 4                        9                       1                     2
#
#    Rest_Between_Events_Days  Fatigue_Score  Performance_Score  \
# ...

# %%
df.loc[df['Team_Contribution_Score']> 90]
# Out:
#     Athlete_ID  Age   Genre  Taille_cm  Poids_kg    Poste  Training_Intensity  \
# 10        A011   24  Female        176        78    Guard                   8
# 13        A014   22  Female        181        90  Forward                   9
# 17        A018   22    Male        197        78    Guard                   5
# 22        A023   19    Male        180        67   Center                   8
# 25        A026   18  Female        187        89  Forward                   7
# 26        A027   21    Male        192        95    Guard                   3
# 41        A042   23    Male        194        82    Guard                   3
# 44        A045   20  Female        191        73   Center                   8
# 51        A052   20    Male        162        90    Guard                   4
# 53        A054   22  Female        183        70  Forward                   4
# 59        A060   21    Male        161        85  Forward                   3
# ...

# %%
# df des blessé(e)s
df_injury = df.loc[df['Injury_Indicator'] == 1].reset_index()
df_injury[['Team_Contribution_Score','Injury_Indicator']]
# Out:
#     Team_Contribution_Score  Injury_Indicator
# 0                        56                 1
# 1                        81                 1
# 2                        69                 1
# 3                        93                 1
# 4                        81                 1
# 5                        90                 1
# 6                        75                 1
# 7                        92                 1
# 8                        67                 1
# 9                        74                 1
# 10                       51                 1
# 11                       83                 1
# 12                       83                 1
# 13                       53                 1
